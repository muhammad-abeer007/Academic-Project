# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, classification_report
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('school_attend.csv')

pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
df
# Out:
#     Sleeping_place_fixed_or_not    Division        Work_hour             Age  \
# 0                           Yes       Dhaka         upto 8hr  from 11  to 14
# 1                           Yes       Dhaka  more than 12 hr    more than 14
# 2                           Yes       Dhaka         upto 8hr  from 11  to 14
# 3                           Yes       Dhaka  from 8 to 12 hr    less than 11
# 4                           Yes       Dhaka         upto 8hr  from 11  to 14
# 5                           Yes       Dhaka         upto 8hr  from 11  to 14
# 6                           Yes       Dhaka         upto 8hr  from 11  to 14
# 7                           Yes       Dhaka  more than 12 hr    more than 14
# 8                            No       Dhaka         upto 8hr    less than 11
# 9                           Yes       Dhaka  more than 12 hr    more than 14
# 10                          Yes       Dhaka         upto 8hr  from 11  to 14
# 11                          Yes       Dhaka  from 8 to 12 hr    more than 14
# 12                          Yes       Dhaka         upto 8hr    more than 14
# 13                           No       Dhaka         upto 8hr    less than 11
# 14                          Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 15                          Yes       Dhaka  more than 12 hr  from 11  to 14
# 16                          Yes       Dhaka  from 8 to 12 hr    more than 14
# 17                          Yes       Dhaka         upto 8hr    less than 11
# 18                          Yes       Dhaka         upto 8hr  from 11  to 14
# 19                          Yes       Dhaka         upto 8hr  from 11  to 14
# 20                          Yes       Dhaka  from 8 to 12 hr    more than 14
# 21                          Yes       Dhaka         upto 8hr  from 11  to 14
# 22                          Yes       Dhaka         upto 8hr  from 11  to 14
# 23                          Yes       Dhaka  from 8 to 12 hr    more than 14
# 24                          Yes       Dhaka  more than 12 hr    more than 14
# 25                          Yes       Dhaka         upto 8hr  from 11  to 14
# 26                          Yes       Dhaka  from 8 to 12 hr    more than 14
# 27                          Yes       Dhaka         upto 8hr  from 11  to 14
# 28                          Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 29                          Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 30                          Yes       Dhaka  more than 12 hr  from 11  to 14
# 31                           No       Dhaka         upto 8hr    more than 14
# 32                          Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 33                           No       Dhaka  from 8 to 12 hr  from 11  to 14
# 34                          Yes       Dhaka  from 8 to 12 hr    more than 14
# 35                          Yes       Dhaka  more than 12 hr  from 11  to 14
# 36                          Yes       Dhaka  more than 12 hr    less than 11
# 37                          Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 38                          Yes       Dhaka  from 8 to 12 hr    more than 14
# 39                          Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 40                          Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 41                          Yes       Dhaka  from 8 to 12 hr    more than 14
# 42                          Yes       Dhaka         upto 8hr  from 11  to 14
# 43                          Yes       Dhaka         upto 8hr  from 11  to 14
# 44                          Yes       Dhaka         upto 8hr  from 11  to 14
# 45                          Yes       Dhaka         upto 8hr  from 11  to 14
# 46                          Yes       Dhaka         upto 8hr  from 11  to 14
# 47                          Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 48                          Yes       Dhaka         upto 8hr  from 11  to 14
# 49                          Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 50                          Yes       Dhaka         upto 8hr    less than 11
# 51                          Yes       Dhaka         upto 8hr  from 11  to 14
# 52                          Yes       Dhaka  from 8 to 12 hr    more than 14
# 53                          Yes       Dhaka         upto 8hr    more than 14
# 54                          Yes       Dhaka  from 8 to 12 hr    more than 14
# 55                           No       Dhaka  more than 12 hr  from 11  to 14
# 56                           No       Dhaka  from 8 to 12 hr    more than 14
# 57                          Yes       Dhaka  more than 12 hr  from 11  to 14
# 58                           No       Dhaka  from 8 to 12 hr  from 11  to 14
# 59                           No       Dhaka         upto 8hr    less than 11
# 60                          Yes       Dhaka  more than 12 hr    less than 11
# 61                           No       Dhaka  more than 12 hr  from 11  to 14
# 62                          Yes       Dhaka  more than 12 hr    more than 14
# 63                           No       Dhaka  more than 12 hr  from 11  to 14
# 64                          Yes       Dhaka         upto 8hr  from 11  to 14
# 65                           No       Dhaka  from 8 to 12 hr    less than 11
# 66                           No       Dhaka  more than 12 hr    less than 11
# 67                          Yes       Dhaka         upto 8hr  from 11  to 14
# 68                          Yes       Dhaka  more than 12 hr    less than 11
# 69                          Yes       Dhaka  from 8 to 12 hr    more than 14
# 70                          Yes       Dhaka  from 8 to 12 hr    less than 11
# 71                          Yes       Dhaka  more than 12 hr    more than 14
# 72                          Yes       Dhaka  from 8 to 12 hr    more than 14
# 73                          Yes       Dhaka  from 8 to 12 hr    less than 11
# 74                           No       Dhaka         upto 8hr  from 11  to 14
# 75                          Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 76                           No       Dhaka  from 8 to 12 hr    less than 11
# 77                           No       Dhaka         upto 8hr  from 11  to 14
# 78                          Yes       Dhaka  more than 12 hr  from 11  to 14
# 79                          Yes       Dhaka  from 8 to 12 hr    more than 14
# 80                           No       Dhaka         upto 8hr  from 11  to 14
# 81                           No       Dhaka         upto 8hr  from 11  to 14
# 82                           No       Dhaka         upto 8hr  from 11  to 14
# 83                           No       Dhaka         upto 8hr  from 11  to 14
# 84                           No       Dhaka  from 8 to 12 hr  from 11  to 14
# 85                           No       Dhaka  from 8 to 12 hr    more than 14
# 86                           No       Dhaka         upto 8hr    more than 14
# 87                           No       Dhaka  from 8 to 12 hr  from 11  to 14
# 88                           No       Dhaka         upto 8hr  from 11  to 14
# 89                           No       Dhaka         upto 8hr    more than 14
# 90                           No       Dhaka  from 8 to 12 hr  from 11  to 14
# 91                           No       Dhaka         upto 8hr  from 11  to 14
# 92                           No       Dhaka         upto 8hr    more than 14
# 93                           No       Dhaka         upto 8hr    less than 11
# 94                           No       Dhaka  from 8 to 12 hr  from 11  to 14
# 95                           No       Dhaka  from 8 to 12 hr  from 11  to 14
# 96                           No       Dhaka  from 8 to 12 hr  from 11  to 14
# 97                           No       Dhaka  from 8 to 12 hr  from 11  to 14
# 98                           No       Dhaka  from 8 to 12 hr  from 11  to 14
# 99                           No       Dhaka         upto 8hr  from 11  to 14
# 100                         Yes       Dhaka         upto 8hr  from 11  to 14
# 101                          No       Dhaka         upto 8hr    more than 14
# 102                          No       Dhaka         upto 8hr  from 11  to 14
# 103                         Yes       Dhaka         upto 8hr  from 11  to 14
# 104                          No       Dhaka  from 8 to 12 hr    less than 11
# 105                         Yes       Dhaka         upto 8hr  from 11  to 14
# 106                         Yes       Dhaka  from 8 to 12 hr    less than 11
# 107                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 108                         Yes       Dhaka         upto 8hr    less than 11
# 109                         Yes       Dhaka         upto 8hr    more than 14
# 110                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 111                         Yes       Dhaka         upto 8hr    less than 11
# 112                         Yes       Dhaka         upto 8hr  from 11  to 14
# 113                         Yes       Dhaka         upto 8hr  from 11  to 14
# 114                         Yes       Dhaka         upto 8hr  from 11  to 14
# 115                         Yes       Dhaka         upto 8hr  from 11  to 14
# 116                         Yes       Dhaka         upto 8hr    less than 11
# 117                         Yes       Dhaka  more than 12 hr  from 11  to 14
# 118                         Yes       Dhaka         upto 8hr  from 11  to 14
# 119                         Yes       Dhaka  from 8 to 12 hr    more than 14
# 120                         Yes       Dhaka         upto 8hr  from 11  to 14
# 121                         Yes       Dhaka         upto 8hr  from 11  to 14
# 122                         Yes       Dhaka         upto 8hr  from 11  to 14
# 123                         Yes       Dhaka         upto 8hr    more than 14
# 124                         Yes       Dhaka         upto 8hr  from 11  to 14
# 125                         Yes       Dhaka         upto 8hr    less than 11
# 126                         Yes       Dhaka         upto 8hr    more than 14
# 127                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 128                          No       Dhaka         upto 8hr    more than 14
# 129                          No       Dhaka         upto 8hr  from 11  to 14
# 130                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 131                          No       Dhaka  from 8 to 12 hr  from 11  to 14
# 132                          No       Dhaka  from 8 to 12 hr    more than 14
# 133                          No       Dhaka  from 8 to 12 hr    less than 11
# 134                          No       Dhaka         upto 8hr  from 11  to 14
# 135                          No       Dhaka  from 8 to 12 hr  from 11  to 14
# 136                          No       Dhaka  from 8 to 12 hr    less than 11
# 137                          No       Dhaka  from 8 to 12 hr    less than 11
# 138                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 139                         Yes       Dhaka         upto 8hr  from 11  to 14
# 140                          No       Dhaka  from 8 to 12 hr  from 11  to 14
# 141                         Yes       Dhaka         upto 8hr    less than 11
# 142                          No       Dhaka         upto 8hr  from 11  to 14
# 143                         Yes       Dhaka  from 8 to 12 hr    more than 14
# 144                         Yes       Dhaka  more than 12 hr  from 11  to 14
# 145                         Yes       Dhaka  more than 12 hr    less than 11
# 146                         Yes       Dhaka  from 8 to 12 hr    less than 11
# 147                         Yes       Dhaka  from 8 to 12 hr    less than 11
# 148                         Yes       Dhaka  from 8 to 12 hr    more than 14
# 149                         Yes       Dhaka  more than 12 hr  from 11  to 14
# 150                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 151                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 152                         Yes       Dhaka  more than 12 hr  from 11  to 14
# 153                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 154                         Yes       Dhaka  from 8 to 12 hr    less than 11
# 155                         Yes       Dhaka         upto 8hr    more than 14
# 156                         Yes       Dhaka  from 8 to 12 hr    more than 14
# 157                         Yes       Dhaka         upto 8hr  from 11  to 14
# 158                         Yes       Dhaka         upto 8hr    less than 11
# 159                         Yes       Dhaka  from 8 to 12 hr    less than 11
# 160                         Yes       Dhaka         upto 8hr  from 11  to 14
# 161                         Yes       Dhaka         upto 8hr  from 11  to 14
# 162                         Yes       Dhaka         upto 8hr    more than 14
# 163                         Yes       Dhaka         upto 8hr  from 11  to 14
# 164                         Yes       Dhaka         upto 8hr  from 11  to 14
# 165                         Yes       Dhaka         upto 8hr  from 11  to 14
# 166                         Yes       Dhaka         upto 8hr  from 11  to 14
# 167                          No       Dhaka         upto 8hr    less than 11
# 168                          No       Dhaka         upto 8hr  from 11  to 14
# 169                         Yes       Dhaka  from 8 to 12 hr    less than 11
# 170                         Yes       Dhaka         upto 8hr  from 11  to 14
# 171                         Yes       Dhaka         upto 8hr    less than 11
# 172                         Yes       Dhaka         upto 8hr  from 11  to 14
# 173                         Yes       Dhaka         upto 8hr    less than 11
# 174                         Yes       Dhaka  from 8 to 12 hr    less than 11
# 175                         Yes       Dhaka         upto 8hr    less than 11
# 176                         Yes       Dhaka  more than 12 hr    more than 14
# 177                         Yes       Dhaka         upto 8hr  from 11  to 14
# 178                         Yes       Dhaka         upto 8hr    less than 11
# 179                         Yes       Dhaka         upto 8hr  from 11  to 14
# 180                          No       Dhaka         upto 8hr  from 11  to 14
# 181                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 182                         Yes  Chittagong         upto 8hr  from 11  to 14
# 183                         Yes  Chittagong         upto 8hr  from 11  to 14
# 184                          No  Chittagong         upto 8hr  from 11  to 14
# 185                          No  Chittagong  from 8 to 12 hr    more than 14
# 186                         Yes  Chittagong         upto 8hr  from 11  to 14
# 187                          No  Chittagong         upto 8hr  from 11  to 14
# 188                          No  Chittagong         upto 8hr  from 11  to 14
# 189                          No  Chittagong         upto 8hr  from 11  to 14
# 190                          No  Chittagong         upto 8hr  from 11  to 14
# 191                         Yes  Chittagong  from 8 to 12 hr  from 11  to 14
# 192                         Yes  Chittagong  from 8 to 12 hr  from 11  to 14
# 193                          No  Chittagong         upto 8hr  from 11  to 14
# 194                          No  Chittagong         upto 8hr  from 11  to 14
# 195                          No  Chittagong         upto 8hr    more than 14
# 196                          No  Chittagong         upto 8hr    more than 14
# 197                          No  Chittagong         upto 8hr    less than 11
# 198                          No  Chittagong         upto 8hr    less than 11
# 199                          No  Chittagong         upto 8hr  from 11  to 14
# 200                          No  Chittagong         upto 8hr    less than 11
# 201                          No  Chittagong         upto 8hr  from 11  to 14
# 202                          No  Chittagong  from 8 to 12 hr  from 11  to 14
# 203                          No  Chittagong         upto 8hr    less than 11
# 204                          No  Chittagong         upto 8hr  from 11  to 14
# 205                          No  Chittagong         upto 8hr  from 11  to 14
# 206                          No  Chittagong  from 8 to 12 hr    less than 11
# 207                          No  Chittagong         upto 8hr  from 11  to 14
# 208                          No  Chittagong         upto 8hr  from 11  to 14
# 209                          No  Chittagong         upto 8hr    less than 11
# 210                          No  Chittagong         upto 8hr  from 11  to 14
# 211                         Yes  Chittagong  from 8 to 12 hr    less than 11
# 212                          No  Chittagong  from 8 to 12 hr  from 11  to 14
# 213                         Yes  Chittagong         upto 8hr  from 11  to 14
# 214                          No  Chittagong  from 8 to 12 hr  from 11  to 14
# 215                         Yes  Chittagong  from 8 to 12 hr    less than 11
# 216                         Yes  Chittagong  more than 12 hr    less than 11
# 217                          No  Chittagong  from 8 to 12 hr    less than 11
# 218                          No  Chittagong         upto 8hr  from 11  to 14
# 219                          No  Chittagong         upto 8hr    less than 11
# 220                          No  Chittagong  from 8 to 12 hr  from 11  to 14
# 221                          No  Chittagong         upto 8hr  from 11  to 14
# 222                          No  Chittagong         upto 8hr  from 11  to 14
# 223                          No  Chittagong  from 8 to 12 hr  from 11  to 14
# 224                         Yes  Chittagong         upto 8hr  from 11  to 14
# 225                         Yes  Chittagong         upto 8hr  from 11  to 14
# 226                         Yes  Chittagong         upto 8hr  from 11  to 14
# 227                          No  Chittagong         upto 8hr    less than 11
# 228                          No  Chittagong         upto 8hr  from 11  to 14
# 229                          No  Chittagong         upto 8hr  from 11  to 14
# 230                         Yes  Chittagong  from 8 to 12 hr  from 11  to 14
# 231                         Yes  Chittagong         upto 8hr  from 11  to 14
# 232                         Yes  Chittagong  from 8 to 12 hr  from 11  to 14
# 233                          No  Chittagong         upto 8hr  from 11  to 14
# 234                          No  Chittagong         upto 8hr    more than 14
# 235                         Yes  Chittagong         upto 8hr    less than 11
# 236                          No  Chittagong  from 8 to 12 hr  from 11  to 14
# 237                         Yes  Chittagong  from 8 to 12 hr  from 11  to 14
# 238                          No  Chittagong         upto 8hr    more than 14
# 239                         Yes  Chittagong         upto 8hr  from 11  to 14
# 240                         Yes  Chittagong         upto 8hr    less than 11
# 241                         Yes  Chittagong  from 8 to 12 hr  from 11  to 14
# 242                         Yes  Chittagong         upto 8hr    less than 11
# 243                         Yes  Chittagong  from 8 to 12 hr  from 11  to 14
# 244                         Yes  Chittagong  from 8 to 12 hr    more than 14
# 245                          No  Chittagong         upto 8hr  from 11  to 14
# 246                          No  Chittagong  from 8 to 12 hr    more than 14
# 247                          No  Chittagong         upto 8hr  from 11  to 14
# 248                         Yes    Rajshahi  more than 12 hr  from 11  to 14
# 249                         Yes    Rajshahi         upto 8hr  from 11  to 14
# 250                         Yes    Rajshahi         upto 8hr  from 11  to 14
# 251                         Yes    Rajshahi  from 8 to 12 hr    less than 11
# 252                         Yes    Rajshahi         upto 8hr  from 11  to 14
# 253                         Yes    Rajshahi         upto 8hr  from 11  to 14
# 254                         Yes    Rajshahi  from 8 to 12 hr    less than 11
# 255                         Yes    Rajshahi         upto 8hr  from 11  to 14
# 256                         Yes    Rajshahi  from 8 to 12 hr  from 11  to 14
# 257                          No    Rajshahi         upto 8hr  from 11  to 14
# 258                         Yes    Rajshahi  more than 12 hr  from 11  to 14
# 259                         Yes    Rajshahi  more than 12 hr    more than 14
# 260                          No    Rajshahi  from 8 to 12 hr  from 11  to 14
# 261                         Yes    Rajshahi  from 8 to 12 hr    less than 11
# 262                         Yes    Rajshahi  from 8 to 12 hr    less than 11
# 263                         Yes    Rajshahi  from 8 to 12 hr  from 11  to 14
# 264                         Yes    Rajshahi  from 8 to 12 hr  from 11  to 14
# 265                         Yes    Rajshahi  from 8 to 12 hr  from 11  to 14
# 266                         Yes    Rajshahi         upto 8hr    less than 11
# 267                         Yes    Rajshahi  from 8 to 12 hr  from 11  to 14
# 268                         Yes    Rajshahi  more than 12 hr    more than 14
# 269                         Yes    Rajshahi  from 8 to 12 hr  from 11  to 14
# 270                         Yes    Rajshahi  from 8 to 12 hr    more than 14
# 271                         Yes    Rajshahi  from 8 to 12 hr  from 11  to 14
# 272                         Yes    Rajshahi         upto 8hr  from 11  to 14
# 273                         Yes    Rajshahi         upto 8hr  from 11  to 14
# 274                         Yes    Rajshahi  from 8 to 12 hr  from 11  to 14
# 275                         Yes    Rajshahi  from 8 to 12 hr  from 11  to 14
# 276                         Yes    Rajshahi  from 8 to 12 hr  from 11  to 14
# 277                         Yes    Rajshahi  from 8 to 12 hr  from 11  to 14
# 278                         Yes    Rajshahi  from 8 to 12 hr  from 11  to 14
# 279                         Yes    Rajshahi         upto 8hr  from 11  to 14
# 280                         Yes    Rajshahi  from 8 to 12 hr    more than 14
# 281                         Yes    Rajshahi  from 8 to 12 hr  from 11  to 14
# 282                         Yes    Rajshahi  from 8 to 12 hr  from 11  to 14
# 283                         Yes    Rajshahi  from 8 to 12 hr  from 11  to 14
# 284                         Yes    Rajshahi  more than 12 hr  from 11  to 14
# 285                         Yes    Rajshahi  from 8 to 12 hr  from 11  to 14
# 286                          No    Rajshahi  from 8 to 12 hr  from 11  to 14
# 287                         Yes    Rajshahi         upto 8hr    less than 11
# 288                         Yes    Rajshahi  from 8 to 12 hr    more than 14
# 289                          No    Rajshahi         upto 8hr    less than 11
# 290                         Yes    Rajshahi         upto 8hr  from 11  to 14
# 291                         Yes    Rajshahi  from 8 to 12 hr    less than 11
# 292                         Yes    Rajshahi         upto 8hr  from 11  to 14
# 293                         Yes    Rajshahi  from 8 to 12 hr    less than 11
# 294                         Yes    Rajshahi  from 8 to 12 hr  from 11  to 14
# 295                         Yes    Rajshahi         upto 8hr    more than 14
# 296                         Yes    Rajshahi         upto 8hr  from 11  to 14
# 297                         Yes    Rajshahi         upto 8hr  from 11  to 14
# 298                         Yes    Rajshahi         upto 8hr  from 11  to 14
# 299                         Yes    Rajshahi         upto 8hr  from 11  to 14
# 300                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 301                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 302                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 303                         Yes       Dhaka         upto 8hr    more than 14
# 304                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 305                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 306                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 307                         Yes       Dhaka         upto 8hr    less than 11
# 308                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 309                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 310                         Yes       Dhaka         upto 8hr    less than 11
# 311                         Yes       Dhaka         upto 8hr    less than 11
# 312                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 313                         Yes       Dhaka  more than 12 hr    less than 11
# 314                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 315                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 316                         Yes       Dhaka  from 8 to 12 hr    less than 11
# 317                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 318                         Yes       Dhaka  more than 12 hr  from 11  to 14
# 319                         Yes       Dhaka  more than 12 hr  from 11  to 14
# 320                         Yes       Dhaka  more than 12 hr  from 11  to 14
# 321                         Yes       Dhaka         upto 8hr  from 11  to 14
# 322                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 323                         Yes       Dhaka         upto 8hr  from 11  to 14
# 324                         Yes       Dhaka  from 8 to 12 hr    less than 11
# 325                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 326                         Yes       Dhaka         upto 8hr  from 11  to 14
# 327                         Yes       Dhaka         upto 8hr  from 11  to 14
# 328                         Yes       Dhaka         upto 8hr    less than 11
# 329                         Yes       Dhaka  from 8 to 12 hr    less than 11
# 330                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 331                         Yes       Dhaka         upto 8hr    more than 14
# 332                         Yes       Dhaka         upto 8hr  from 11  to 14
# 333                         Yes       Dhaka  from 8 to 12 hr    more than 14
# 334                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 335                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 336                         Yes       Dhaka         upto 8hr  from 11  to 14
# 337                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 338                         Yes       Dhaka  from 8 to 12 hr  from 11  to 14
# 339                         Yes       Dhaka         upto 8hr  from 11  to 14
# 340                         Yes       Dhaka  from 8 to 12 hr    more than 14
# 341                         Yes      Sylhet  from 8 to 12 hr    more than 14
# 342                         Yes      Sylhet  from 8 to 12 hr  from 11  to 14
# 343                         Yes      Sylhet  from 8 to 12 hr    more than 14
# 344                         Yes      Sylhet  from 8 to 12 hr    less than 11
# 345                         Yes      Sylhet         upto 8hr    less than 11
# 346                         Yes      Sylhet         upto 8hr  from 11  to 14
# 347                         Yes      Sylhet         upto 8hr    more than 14
# 348                         Yes      Sylhet  from 8 to 12 hr  from 11  to 14
# 349                         Yes      Sylhet  more than 12 hr    more than 14
# 350                         Yes      Sylhet  from 8 to 12 hr  from 11  to 14
# 351                         Yes      Sylhet  more than 12 hr    more than 14
# 352                         Yes      Sylhet         upto 8hr    less than 11
# 353                         Yes      Sylhet  more than 12 hr  from 11  to 14
# 354                         Yes      Sylhet         upto 8hr    more than 14
# 355                         Yes      Sylhet         upto 8hr  from 11  to 14
# 356                         Yes      Sylhet  more than 12 hr    less than 11
# 357                         Yes      Sylhet  from 8 to 12 hr  from 11  to 14
# 358                         Yes      Sylhet  from 8 to 12 hr    less than 11
# 359                         Yes      Sylhet         upto 8hr  from 11  to 14
# 360                         Yes      Sylhet  from 8 to 12 hr    less than 11
# 361                         Yes      Sylhet         upto 8hr  from 11  to 14
# 362                         Yes      Sylhet         upto 8hr  from 11  to 14
# 363                         Yes      Sylhet  from 8 to 12 hr    more than 14
# 364                         Yes      Sylhet         upto 8hr  from 11  to 14
# 365                         Yes      Sylhet         upto 8hr  from 11  to 14
# 366                         Yes      Sylhet         upto 8hr  from 11  to 14
# 367                          No      Sylhet         upto 8hr  from 11  to 14
# 368                         Yes      Sylhet  from 8 to 12 hr  from 11  to 14
# 369                          No      Sylhet  from 8 to 12 hr    more than 14
# 370                         Yes      Sylhet  from 8 to 12 hr  from 11  to 14
# 371                         Yes      Sylhet         upto 8hr  from 11  to 14
# 372                         Yes      Sylhet  from 8 to 12 hr    less than 11
# 373                         Yes      Sylhet  from 8 to 12 hr    more than 14
# 374                         Yes      Sylhet         upto 8hr  from 11  to 14
# 375                         Yes      Sylhet  from 8 to 12 hr  from 11  to 14
# 376                         Yes      Sylhet  from 8 to 12 hr    less than 11
# 377                         Yes      Sylhet  from 8 to 12 hr    less than 11
# 378                         Yes      Sylhet         upto 8hr  from 11  to 14
# 379                         Yes      Sylhet  from 8 to 12 hr  from 11  to 14
# 380                         Yes      Sylhet  from 8 to 12 hr  from 11  to 14
# 381                         Yes      Sylhet         upto 8hr    less than 11
# 382                         Yes      Sylhet         upto 8hr    less than 11
# 383                          No      Sylhet  from 8 to 12 hr    more than 14
# 384                         Yes      Sylhet  from 8 to 12 hr    less than 11
# 385                          No      Sylhet  from 8 to 12 hr  from 11  to 14
# 386                         Yes      Sylhet  more than 12 hr    more than 14
# 387                         Yes      Sylhet  from 8 to 12 hr    more than 14
# 388                         Yes      Sylhet         upto 8hr    more than 14
# 389                         Yes      Sylhet  from 8 to 12 hr  from 11  to 14
# 390                         Yes      Sylhet         upto 8hr    less than 11
# 391                         Yes      Sylhet  from 8 to 12 hr  from 11  to 14
# 392                         Yes      Sylhet  from 8 to 12 hr    less than 11
# 393                         Yes      Sylhet  from 8 to 12 hr    more than 14
# 394                         Yes      Sylhet  from 8 to 12 hr  from 11  to 14
# 395                         Yes      Sylhet  more than 12 hr    more than 14
# 396                         Yes      Sylhet  from 8 to 12 hr    more than 14
# 397                         Yes      Khulna  from 8 to 12 hr    more than 14
# 398                         Yes      Khulna  from 8 to 12 hr    more than 14
# 399                         Yes      Khulna         upto 8hr  from 11  to 14
# 400                         Yes      Khulna  more than 12 hr  from 11  to 14
# 401                         Yes      Khulna  from 8 to 12 hr    more than 14
# 402                         Yes      Khulna         upto 8hr  from 11  to 14
# 403                         Yes      Khulna  more than 12 hr  from 11  to 14
# 404                         Yes      Khulna         upto 8hr  from 11  to 14
# 405                         Yes      Khulna  from 8 to 12 hr  from 11  to 14
# 406                         Yes      Khulna  more than 12 hr    more than 14
# 407                         Yes      Khulna  more than 12 hr    more than 14
# 408                         Yes      Khulna  more than 12 hr    less than 11
# 409                         Yes      Khulna  more than 12 hr    less than 11
# 410                          No      Khulna         upto 8hr  from 11  to 14
# 411                          No      Khulna  from 8 to 12 hr  from 11  to 14
# 412                         Yes      Khulna  from 8 to 12 hr  from 11  to 14
# 413                         Yes      Khulna         upto 8hr    less than 11
# 414                         Yes      Khulna  from 8 to 12 hr    less than 11
# 415                         Yes      Khulna  from 8 to 12 hr  from 11  to 14
# 416                         Yes      Khulna  from 8 to 12 hr  from 11  to 14
# 417                         Yes      Khulna  from 8 to 12 hr    less than 11
# 418                         Yes      Khulna  more than 12 hr    less than 11
# 419                         Yes      Khulna  from 8 to 12 hr    less than 11
# 420                         Yes      Khulna  from 8 to 12 hr  from 11  to 14
# 421                         Yes      Khulna         upto 8hr  from 11  to 14
# 422                         Yes      Khulna  more than 12 hr  from 11  to 14
# 423                         Yes      Khulna         upto 8hr    less than 11
# 424                         Yes       Dhaka  from 8 to 12 hr    less than 11
# 425                         Yes       Dhaka         upto 8hr  from 11  to 14
# 426                         Yes     Barisal         upto 8hr    less than 11
# 427                         Yes     Barisal         upto 8hr  from 11  to 14
# 428                         Yes     Barisal         upto 8hr  from 11  to 14
# 429                         Yes     Barisal  from 8 to 12 hr    more than 14
# 430                         Yes     Barisal         upto 8hr    more than 14
# 431                         Yes     Barisal         upto 8hr    less than 11
# 432                         Yes     Barisal         upto 8hr  from 11  to 14
# 433                         Yes     Barisal         upto 8hr  from 11  to 14
# 434                         Yes     Barisal         upto 8hr  from 11  to 14
# 435                         Yes     Barisal         upto 8hr    more than 14
# 436                         Yes     Barisal         upto 8hr    less than 11
# 437                         Yes     Barisal         upto 8hr  from 11  to 14
# 438                         Yes     Barisal         upto 8hr  from 11  to 14
# 439                         Yes     Barisal         upto 8hr  from 11  to 14
# 440                         Yes     Barisal         upto 8hr    less than 11
# 441                         Yes     Barisal  from 8 to 12 hr  from 11  to 14
# 442                         Yes     Barisal         upto 8hr  from 11  to 14
# 443                         Yes     Barisal         upto 8hr    less than 11
# 444                         Yes     Barisal         upto 8hr  from 11  to 14
# 445                         Yes     Barisal  more than 12 hr    more than 14
# 446                         Yes     Barisal  from 8 to 12 hr    more than 14
# 447                         Yes     Barisal         upto 8hr  from 11  to 14
# 448                         Yes     Barisal         upto 8hr    less than 11
# 449                         Yes     Barisal         upto 8hr    less than 11
#
#                         Eating_location Aware_of_organizations school_attend
# 0                           Street Shop                    Yes            No
# 1                           Street Shop                     No            No
# 2    Begging or collecting from dustbin                    Yes           Yes
# 3    Begging or collecting from dustbin                    Yes           Yes
# 4                           Street Shop                    Yes           Yes
# 5                           Street Shop                    Yes           Yes
# 6    Begging or collecting from dustbin                    Yes            No
# 7                           Street Shop                     No            No
# 8                           Street Shop                    Yes           Yes
# 9                           Street Shop                     No            No
# 10                          Street Shop                     No            No
# 11                          Street Shop                    Yes            No
# 12                          Street Shop                     No            No
# 13                          Street Shop                     No            No
# 14                          Street Shop                     No           Yes
# 15   Begging or collecting from dustbin                     No            No
# 16                          Street Shop                     No           Yes
# 17   Begging or collecting from dustbin                     No            No
# 18   Begging or collecting from dustbin                     No           Yes
# 19   Begging or collecting from dustbin                    Yes           Yes
# 20   Begging or collecting from dustbin                    Yes           Yes
# 21   Begging or collecting from dustbin                    Yes           Yes
# 22   Begging or collecting from dustbin                    Yes            No
# 23   Begging or collecting from dustbin                     No            No
# 24                          Street Shop                     No            No
# 25                          Street Shop                     No            No
# 26                          Street Shop                     No           Yes
# 27   Begging or collecting from dustbin                     No           Yes
# 28                          Street Shop                    Yes           Yes
# 29                          Street Shop                     No            No
# 30                          Street Shop                     No            No
# 31                          Street Shop                     No            No
# 32   Begging or collecting from dustbin                     No           Yes
# 33                          Street Shop                     No           Yes
# 34   Begging or collecting from dustbin                     No           Yes
# 35                          Street Shop                     No           Yes
# 36                          Street Shop                     No            No
# 37                          Street Shop                     No           Yes
# 38                          Street Shop                     No           Yes
# 39   Begging or collecting from dustbin                     No            No
# 40                          Street Shop                     No           Yes
# 41                          Street Shop                     No           Yes
# 42                          Street Shop                    Yes            No
# 43                          Street Shop                     No            No
# 44                          Street Shop                     No           Yes
# 45                          Street Shop                     No            No
# 46                          Street Shop                     No            No
# 47                          Street Shop                     No            No
# 48                          Street Shop                    Yes            No
# 49                          Street Shop                    Yes           Yes
# 50                          Street Shop                     No            No
# 51                          Street Shop                     No            No
# 52                          Street Shop                     No            No
# 53                          Street Shop                     No            No
# 54                          Street Shop                     No            No
# 55                          Street Shop                     No            No
# 56                          Street Shop                     No            No
# 57                          Street Shop                     No           Yes
# 58                          Street Shop                    Yes           Yes
# 59                          Street Shop                     No            No
# 60                          Street Shop                     No           Yes
# 61                          Street Shop                     No           Yes
# 62                          Street Shop                     No           Yes
# 63   Begging or collecting from dustbin                     No           Yes
# 64                          Street Shop                     No           Yes
# 65   Begging or collecting from dustbin                     No           Yes
# 66   Begging or collecting from dustbin                     No            No
# 67   Begging or collecting from dustbin                     No           Yes
# 68                          Street Shop                     No           Yes
# 69   Begging or collecting from dustbin                     No            No
# 70   Begging or collecting from dustbin                     No            No
# 71                          Street Shop                     No            No
# 72                          Street Shop                     No            No
# 73                          Street Shop                     No            No
# 74                          Street Shop                     No            No
# 75                          Street Shop                     No            No
# 76                          Street Shop                     No            No
# 77                          Street Shop                     No            No
# 78   Begging or collecting from dustbin                    Yes           Yes
# 79                          Street Shop                     No            No
# 80                          Street Shop                     No            No
# 81                          Street Shop                     No            No
# 82                          Street Shop                     No            No
# 83                          Street Shop                     No            No
# 84                          Street Shop                     No            No
# 85                          Street Shop                     No            No
# 86                          Street Shop                     No            No
# 87                          Street Shop                     No           Yes
# 88                          Street Shop                     No            No
# 89                          Street Shop                     No            No
# 90                          Street Shop                     No            No
# 91                          Street Shop                     No            No
# 92                          Street Shop                     No            No
# 93                          Street Shop                     No            No
# 94                          Street Shop                     No            No
# 95                          Street Shop                     No            No
# 96                          Street Shop                     No            No
# 97                          Street Shop                     No            No
# 98                          Street Shop                     No           Yes
# 99                          Street Shop                     No            No
# 100                         Street Shop                     No            No
# 101                         Street Shop                     No            No
# 102                         Street Shop                     No            No
# 103  Begging or collecting from dustbin                     No           Yes
# 104                         Street Shop                     No            No
# 105                         Street Shop                     No            No
# 106                         Street Shop                     No            No
# 107                         Street Shop                     No           Yes
# 108                         Street Shop                     No            No
# 109                         Street Shop                     No            No
# 110                         Street Shop                     No            No
# 111                         Street Shop                     No            No
# 112                         Street Shop                     No            No
# 113                         Street Shop                     No            No
# 114                         Street Shop                     No           Yes
# 115                         Street Shop                     No            No
# 116                         Street Shop                     No            No
# 117                         Street Shop                     No           Yes
# 118                         Street Shop                     No            No
# 119                         Street Shop                     No           Yes
# 120                         Street Shop                     No            No
# 121                         Street Shop                     No           Yes
# 122                         Street Shop                     No           Yes
# 123                         Street Shop                     No            No
# 124                         Street Shop                     No           Yes
# 125                         Street Shop                     No            No
# 126                         Street Shop                     No           Yes
# 127                         Street Shop                     No            No
# 128                         Street Shop                     No            No
# 129                         Street Shop                     No            No
# 130  Begging or collecting from dustbin                     No           Yes
# 131  Begging or collecting from dustbin                     No            No
# 132                         Street Shop                     No            No
# 133                         Street Shop                     No           Yes
# 134                         Street Shop                     No            No
# 135                         Street Shop                     No           Yes
# 136                         Street Shop                     No           Yes
# 137                         Street Shop                     No           Yes
# 138                         Street Shop                    Yes            No
# 139                         Street Shop                     No           Yes
# 140                         Street Shop                     No            No
# 141                         Street Shop                     No            No
# 142                         Street Shop                     No            No
# 143                         Street Shop                     No           Yes
# 144                         Street Shop                     No            No
# 145                         Street Shop                     No            No
# 146                         Street Shop                     No           Yes
# 147  Begging or collecting from dustbin                     No            No
# 148                         Street Shop                     No            No
# ...
# 248  Begging or collecting from dustbin                     No            No
# 249                         Street Shop                    Yes           Yes
# 250                         Street Shop                    Yes           Yes
# 251                         Street Shop                     No           Yes
# 252                         Street Shop                     No            No
# 253                         Street Shop                     No            No
# 254  Begging or collecting from dustbin                     No            No
# 255                         Street Shop                     No           Yes
# 256                         Street Shop                     No           Yes
# 257  Begging or collecting from dustbin                     No            No
# 258                         Street Shop                     No           Yes
# 259                         Street Shop                     No            No
# 260                         Street Shop                     No            No
# 261                         Street Shop                     No            No
# 262                         Street Shop                     No           Yes
# 263                         Street Shop                     No           Yes
# 264                         Street Shop                     No           Yes
# 265  Begging or collecting from dustbin                     No           Yes
# 266                         Street Shop                     No            No
# 267                         Street Shop                     No           Yes
# 268                         Street Shop                     No            No
# 269  Begging or collecting from dustbin                     No           Yes
# 270  Begging or collecting from dustbin                     No           Yes
# 271  Begging or collecting from dustbin                     No           Yes
# 272                         Street Shop                     No           Yes
# 273                         Street Shop                     No           Yes
# 274                         Street Shop                     No            No
# 275                         Street Shop                     No           Yes
# 276                         Street Shop                     No           Yes
# 277  Begging or collecting from dustbin                     No           Yes
# 278                         Street Shop                     No           Yes
# 279                         Street Shop                     No           Yes
# 280                         Street Shop                    Yes           Yes
# 281                         Street Shop                     No            No
# 282                         Street Shop                     No            No
# 283                         Street Shop                     No           Yes
# 284                         Street Shop                     No           Yes
# 285                         Street Shop                     No           Yes
# 286  Begging or collecting from dustbin                     No           Yes
# 287                         Street Shop                     No           Yes
# 288                         Street Shop                     No           Yes
# 289                         Street Shop                     No           Yes
# 290  Begging or collecting from dustbin                     No            No
# 291                         Street Shop                     No            No
# 292                         Street Shop                     No           Yes
# 293                         Street Shop                     No            No
# 294                         Street Shop                     No           Yes
# 295                         Street Shop                     No           Yes
# 296                         Street Shop                     No           Yes
# 297                         Street Shop                     No            No
# 298                         Street Shop                     No            No
# 299                         Street Shop                     No           Yes
# 300                         Street Shop                     No           Yes
# 301                         Street Shop                     No           Yes
# 302  Begging or collecting from dustbin                     No           Yes
# 303                         Street Shop                     No            No
# 304                         Street Shop                     No            No
# 305                         Street Shop                     No           Yes
# 306                         Street Shop                     No           Yes
# 307                         Street Shop                     No            No
# 308                         Street Shop                     No           Yes
# 309                         Street Shop                     No            No
# 310                         Street Shop                     No           Yes
# 311                         Street Shop                     No            No
# 312  Begging or collecting from dustbin                     No            No
# 313  Begging or collecting from dustbin                     No            No
# 314                         Street Shop                     No           Yes
# 315                         Street Shop                     No           Yes
# 316                         Street Shop                     No            No
# 317  Begging or collecting from dustbin                     No            No
# 318                         Street Shop                     No            No
# 319                         Street Shop                     No            No
# 320                         Street Shop                     No            No
# 321                         Street Shop                     No           Yes
# 322  Begging or collecting from dustbin                     No           Yes
# 323                         Street Shop                     No            No
# 324                         Street Shop                     No            No
# 325                         Street Shop                     No            No
# 326                         Street Shop                     No            No
# 327                         Street Shop                     No            No
# 328                         Street Shop                     No            No
# 329                         Street Shop                     No            No
# 330                         Street Shop                     No           Yes
# 331                         Street Shop                     No            No
# 332                         Street Shop                     No            No
# 333                         Street Shop                     No            No
# 334                         Street Shop                     No            No
# 335                         Street Shop                     No           Yes
# 336                         Street Shop                     No           Yes
# 337                         Street Shop                     No            No
# 338                         Street Shop                     No            No
# 339                         Street Shop                     No           Yes
# 340                         Street Shop                     No           Yes
# 341                         Street Shop                     No            No
# 342                         Street Shop                     No            No
# 343                         Street Shop                     No            No
# 344                         Street Shop                     No            No
# 345                         Street Shop                     No            No
# 346                         Street Shop                     No           Yes
# 347                         Street Shop                     No            No
# 348                         Street Shop                     No            No
# 349                         Street Shop                     No            No
# 350                         Street Shop                     No            No
# 351                         Street Shop                     No           Yes
# 352                         Street Shop                     No            No
# 353                         Street Shop                     No            No
# 354                         Street Shop                     No            No
# 355                         Street Shop                     No            No
# 356                         Street Shop                     No            No
# 357  Begging or collecting from dustbin                     No            No
# 358                         Street Shop                     No            No
# 359                         Street Shop                     No            No
# 360                         Street Shop                     No            No
# 361                         Street Shop                     No            No
# 362                         Street Shop                     No            No
# 363                         Street Shop                     No            No
# 364                         Street Shop                     No            No
# 365                         Street Shop                     No            No
# 366                         Street Shop                     No           Yes
# 367                         Street Shop                     No           Yes
# 368                         Street Shop                     No            No
# 369                         Street Shop                     No            No
# 370                         Street Shop                     No           Yes
# 371                         Street Shop                     No            No
# 372                         Street Shop                     No            No
# 373                         Street Shop                     No            No
# 374                         Street Shop                     No            No
# 375                         Street Shop                     No            No
# 376                         Street Shop                     No            No
# 377                         Street Shop                     No            No
# 378  Begging or collecting from dustbin                     No            No
# 379                         Street Shop                     No           Yes
# 380                         Street Shop                     No            No
# 381                         Street Shop                     No            No
# 382                         Street Shop                     No           Yes
# 383                         Street Shop                     No            No
# 384                         Street Shop                     No            No
# 385                         Street Shop                     No            No
# 386                         Street Shop                     No            No
# 387                         Street Shop                     No            No
# 388                         Street Shop                     No            No
# 389                         Street Shop                     No           Yes
# 390                         Street Shop                     No            No
# 391                         Street Shop                     No           Yes
# 392                         Street Shop                     No            No
# 393                         Street Shop                     No           Yes
# 394                         Street Shop                     No            No
# 395                         Street Shop                    Yes           Yes
# 396                         Street Shop                     No            No
# 397                         Street Shop                     No            No
# 398                         Street Shop                     No            No
# 399                         Street Shop                     No            No
# 400  Begging or collecting from dustbin                     No           Yes
# 401                         Street Shop                     No            No
# 402                         Street Shop                     No           Yes
# 403                         Street Shop                     No           Yes
# 404                         Street Shop                     No            No
# 405                         Street Shop                     No            No
# 406                         Street Shop                     No            No
# 407                         Street Shop                     No            No
# 408                         Street Shop                     No            No
# 409                         Street Shop                     No            No
# 410                         Street Shop                     No            No
# 411                         Street Shop                     No           Yes
# 412                         Street Shop                     No           Yes
# 413                         Street Shop                     No           Yes
# 414  Begging or collecting from dustbin                     No           Yes
# 415                         Street Shop                     No            No
# 416                         Street Shop                     No           Yes
# 417                         Street Shop                     No            No
# 418                         Street Shop                     No            No
# 419                         Street Shop                     No           Yes
# 420                         Street Shop                     No            No
# 421                         Street Shop                     No            No
# 422                         Street Shop                     No            No
# 423                         Street Shop                     No           Yes
# 424                         Street Shop                     No            No
# 425                         Street Shop                     No           Yes
# 426                         Street Shop                     No           Yes
# 427                         Street Shop                     No            No
# 428                         Street Shop                     No            No
# 429                         Street Shop                     No            No
# 430                         Street Shop                     No            No
# 431                         Street Shop                     No            No
# 432                         Street Shop                     No            No
# 433                         Street Shop                     No            No
# 434                         Street Shop                     No           Yes
# 435                         Street Shop                     No            No
# 436                         Street Shop                     No            No
# 437                         Street Shop                     No           Yes
# 438                         Street Shop                     No            No
# 439                         Street Shop                     No            No
# 440                         Street Shop                     No            No
# 441                         Street Shop                     No           Yes
# 442                         Street Shop                     No            No
# 443  Begging or collecting from dustbin                     No           Yes
# 444                         Street Shop                     No            No
# 445                         Street Shop                     No            No
# 446                         Street Shop                    Yes           Yes
# 447                         Street Shop                     No           Yes
# 448                         Street Shop                     No            No
# 449                         Street Shop                     No            No

# %% [markdown]
# # Creating & Manageing Dummy Variables

# %%
df.columns.values
# Out:
# array(['Sleeping_place_fixed_or_not', 'Division', 'Work_hour', 'Age',
#        'Eating_location', 'Aware_of_organizations', 'school_attend'],
#       dtype=object)

# %%
dummy_df_Age = pd.get_dummies(df['Age'], prefix = 'Age')
dummy_df_Age = dummy_df_Age.astype(int)

# %%
dummy_df_Eat_loc = pd.get_dummies(df['Eating_location'], prefix = 'Eating_location')
dummy_df_Eat_loc = dummy_df_Eat_loc.astype(int)

# %%
dummy_df_Sleeping_place_fixed = pd.get_dummies(df['Sleeping_place_fixed_or_not'], prefix = 'Sleeping_place_fixed')
dummy_df_Sleeping_place_fixed = dummy_df_Sleeping_place_fixed.astype(int)

# %%
dummy_df_Aware_of_organizations = pd.get_dummies(df['Aware_of_organizations'], prefix = 'Aware_of_organizations')
dummy_df_Aware_of_organizations = dummy_df_Aware_of_organizations.astype(int)

# %%
dummy_df_Work_hour = pd.get_dummies(df['Work_hour'], prefix = 'Work_hour')
dummy_df_Work_hour = dummy_df_Work_hour.astype(int)

# %%
dummy_df_Division = pd.get_dummies(df['Division'], prefix = 'Division')
dummy_df_Division = dummy_df_Division.astype(int)

# %%
inputs= pd.concat([dummy_df_Age,dummy_df_Eat_loc,dummy_df_Sleeping_place_fixed,dummy_df_Aware_of_organizations,dummy_df_Work_hour, dummy_df_Division],axis =1)

# %%
inputs.columns.values
# Out:
# array(['Age_from 11  to 14', 'Age_less than 11', 'Age_more than 14',
#        'Eating_location_Begging or collecting from dustbin',
#        'Eating_location_Street Shop', 'Sleeping_place_fixed_No',
#        'Sleeping_place_fixed_Yes', 'Aware_of_organizations_No',
#        'Aware_of_organizations_Yes', 'Work_hour_from 8 to 12 hr',
#        'Work_hour_more than 12 hr', 'Work_hour_upto 8hr',
#        'Division_Barisal', 'Division_Chittagong', 'Division_Dhaka',
#        'Division_Khulna', 'Division_Rajshahi', 'Division_Sylhet'],
#       dtype=object)

# %%
dummies_to_drop= ['Age_from 11  to 14','Eating_location_Street Shop','Sleeping_place_fixed_Yes','Aware_of_organizations_Yes','Work_hour_upto 8hr','Division_Dhaka']

# %% [markdown]
# # Defining Input Dataset

# %%
inputs= inputs.drop(dummies_to_drop,axis=1)

# %%
inputs.shape
# Out:
# (450, 12)

# %% [markdown]
# # Defining Target Dataset

# %%
targets  = df.filter(['school_attend'])

# %%
targets = targets.replace({'Yes' : 1, 'No' : 0})
targets = targets.astype(int)

# %%
targets.value_counts()
# Out:
# school_attend
# 0                273
# 1                177
# Name: count, dtype: int64

# %%
targets
# Out:
#      school_attend
# 0                0
# 1                0
# 2                1
# 3                1
# 4                1
# 5                1
# 6                0
# 7                0
# 8                1
# 9                0
# 10               0
# 11               0
# 12               0
# 13               0
# 14               1
# 15               0
# 16               1
# 17               0
# 18               1
# 19               1
# 20               1
# 21               1
# 22               0
# 23               0
# 24               0
# 25               0
# 26               1
# 27               1
# 28               1
# 29               0
# 30               0
# 31               0
# 32               1
# 33               1
# 34               1
# 35               1
# 36               0
# 37               1
# 38               1
# 39               0
# 40               1
# 41               1
# 42               0
# 43               0
# 44               1
# 45               0
# 46               0
# 47               0
# 48               0
# 49               1
# 50               0
# 51               0
# 52               0
# 53               0
# 54               0
# 55               0
# 56               0
# 57               1
# 58               1
# 59               0
# 60               1
# 61               1
# 62               1
# 63               1
# 64               1
# 65               1
# 66               0
# 67               1
# 68               1
# 69               0
# 70               0
# 71               0
# 72               0
# 73               0
# 74               0
# 75               0
# 76               0
# 77               0
# 78               1
# 79               0
# 80               0
# 81               0
# 82               0
# 83               0
# 84               0
# 85               0
# 86               0
# 87               1
# 88               0
# 89               0
# 90               0
# 91               0
# 92               0
# 93               0
# 94               0
# 95               0
# 96               0
# 97               0
# 98               1
# 99               0
# 100              0
# 101              0
# 102              0
# 103              1
# 104              0
# 105              0
# 106              0
# 107              1
# 108              0
# 109              0
# 110              0
# 111              0
# 112              0
# 113              0
# 114              1
# 115              0
# 116              0
# 117              1
# 118              0
# 119              1
# 120              0
# 121              1
# 122              1
# 123              0
# 124              1
# 125              0
# 126              1
# 127              0
# 128              0
# 129              0
# 130              1
# 131              0
# 132              0
# 133              1
# 134              0
# 135              1
# 136              1
# 137              1
# 138              0
# 139              1
# 140              0
# 141              0
# 142              0
# 143              1
# 144              0
# 145              0
# 146              1
# 147              0
# 148              0
# 149              1
# 150              0
# 151              1
# 152              0
# 153              1
# 154              0
# 155              0
# 156              1
# 157              1
# 158              1
# 159              1
# 160              1
# 161              1
# 162              0
# 163              0
# 164              1
# 165              0
# 166              0
# 167              1
# 168              1
# 169              1
# 170              1
# 171              1
# 172              0
# 173              1
# 174              1
# 175              1
# 176              1
# 177              1
# 178              1
# 179              1
# 180              0
# 181              0
# 182              0
# 183              0
# 184              0
# 185              0
# 186              1
# 187              0
# 188              0
# 189              0
# 190              1
# 191              1
# 192              1
# 193              0
# 194              0
# 195              1
# 196              0
# 197              0
# 198              0
# 199              0
# 200              0
# 201              0
# 202              1
# 203              1
# 204              0
# 205              0
# 206              0
# 207              0
# 208              0
# 209              1
# 210              1
# 211              1
# 212              1
# 213              0
# 214              1
# 215              0
# 216              0
# 217              1
# 218              1
# 219              0
# 220              0
# 221              0
# 222              0
# 223              0
# 224              0
# 225              0
# 226              0
# 227              0
# 228              0
# 229              0
# 230              1
# 231              1
# 232              1
# 233              1
# 234              0
# 235              0
# 236              1
# 237              0
# 238              0
# 239              0
# 240              0
# 241              0
# 242              0
# 243              1
# 244              1
# 245              0
# 246              1
# 247              0
# 248              0
# 249              1
# 250              1
# 251              1
# 252              0
# 253              0
# 254              0
# 255              1
# 256              1
# 257              0
# 258              1
# 259              0
# 260              0
# 261              0
# 262              1
# 263              1
# 264              1
# 265              1
# 266              0
# 267              1
# 268              0
# 269              1
# 270              1
# 271              1
# 272              1
# 273              1
# 274              0
# 275              1
# 276              1
# 277              1
# 278              1
# 279              1
# 280              1
# 281              0
# 282              0
# 283              1
# 284              1
# 285              1
# 286              1
# 287              1
# 288              1
# 289              1
# 290              0
# 291              0
# 292              1
# 293              0
# 294              1
# 295              1
# 296              1
# 297              0
# 298              0
# 299              1
# 300              1
# 301              1
# 302              1
# 303              0
# 304              0
# 305              1
# 306              1
# 307              0
# 308              1
# 309              0
# 310              1
# 311              0
# 312              0
# 313              0
# 314              1
# 315              1
# 316              0
# 317              0
# 318              0
# 319              0
# 320              0
# 321              1
# 322              1
# 323              0
# 324              0
# 325              0
# 326              0
# 327              0
# 328              0
# 329              0
# 330              1
# 331              0
# 332              0
# 333              0
# 334              0
# 335              1
# 336              1
# 337              0
# 338              0
# 339              1
# 340              1
# 341              0
# 342              0
# 343              0
# 344              0
# 345              0
# 346              1
# 347              0
# 348              0
# 349              0
# 350              0
# 351              1
# 352              0
# 353              0
# 354              0
# 355              0
# 356              0
# 357              0
# 358              0
# 359              0
# 360              0
# 361              0
# 362              0
# 363              0
# 364              0
# 365              0
# 366              1
# 367              1
# 368              0
# 369              0
# 370              1
# 371              0
# 372              0
# 373              0
# 374              0
# 375              0
# 376              0
# 377              0
# 378              0
# 379              1
# 380              0
# 381              0
# 382              1
# 383              0
# 384              0
# 385              0
# 386              0
# 387              0
# 388              0
# 389              1
# 390              0
# 391              1
# 392              0
# 393              1
# 394              0
# 395              1
# 396              0
# 397              0
# 398              0
# 399              0
# 400              1
# 401              0
# 402              1
# 403              1
# 404              0
# 405              0
# 406              0
# 407              0
# 408              0
# 409              0
# 410              0
# 411              1
# 412              1
# 413              1
# 414              1
# 415              0
# 416              1
# 417              0
# 418              0
# 419              1
# 420              0
# 421              0
# 422              0
# 423              1
# 424              0
# 425              1
# 426              1
# 427              0
# 428              0
# 429              0
# 430              0
# 431              0
# 432              0
# 433              0
# 434              1
# 435              0
# 436              0
# 437              1
# 438              0
# 439              0
# 440              0
# 441              1
# 442              0
# 443              1
# 444              0
# 445              0
# 446              1
# 447              1
# 448              0
# 449              0

# %% [markdown]
# # Split into Train and Test

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(inputs,targets,train_size = .8,shuffle = True, random_state = 20)

# %% [markdown]
# # Fitting Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression

# %%
reg = LogisticRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
score_train= reg.score(x_train,y_train)
score_test = reg.score(x_test,y_test)
print('\n Train score :', score_train *100 ,'%')
print('\n Test score :', score_test *100 ,'%')
# Out:
#  Train score : 66.11111111111111 %
#
#  Test score : 66.66666666666666 %

# %%
# Predictions
logistic_prediction = reg.predict(x_test)

# Calculate accuracy
logistic_accuracy = accuracy_score(y_test, logistic_prediction)

# Print classification report
logistic_classification_report = classification_report(y_test, logistic_prediction)
print(f"logistic Accuracy: {logistic_accuracy}")
print(f"logistic Classification Report:\n{logistic_classification_report}")
# Out:
# logistic Accuracy: 0.6666666666666666
# logistic Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.81      0.75        57
#            1       0.56      0.42      0.48        33
#
#     accuracy                           0.67        90
#    macro avg       0.63      0.62      0.62        90
# weighted avg       0.65      0.67      0.65        90

# %%
type(logistic_classification_report)
# Out:
# str

# %% [markdown]
# # Fitting SVM

# %%
from sklearn.svm import SVC
svm_classifier = SVC(kernel='linear', C=1.0, random_state=42)  # You can choose different kernels and hyperparameters
svm_classifier.fit(x_train, y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
# Predictions
svm_predictions = svm_classifier.predict(x_test)
# Calculate accuracy
svm_accuracy = accuracy_score(y_test, svm_predictions)
# Print classification report
svm_classification_report = classification_report(y_test, svm_predictions)

# %%
print(f"SVM Accuracy: {svm_accuracy}")
print(f"SVM Classification Report:\n{svm_classification_report}")
# Out:
# SVM Accuracy: 0.6888888888888889
# SVM Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.91      0.79        57
#            1       0.67      0.30      0.42        33
#
#     accuracy                           0.69        90
#    macro avg       0.68      0.61      0.60        90
# weighted avg       0.68      0.69      0.65        90

# %% [markdown]
# # Fitting Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)  # You can adjust the number of trees and other hyperparameters
rf_classifier.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
#Predictions
rf_predictions = rf_classifier.predict(x_test)

# Calculate accuracy
rf_accuracy = accuracy_score(y_test, rf_predictions)

# Print classification report
rf_classification_report = classification_report(y_test, rf_predictions)

# %%
print(f"Random Forest Accuracy: {rf_accuracy}")
print(f"Random Forest Classification Report:\n{rf_classification_report}")
# Out:
# Random Forest Accuracy: 0.5888888888888889
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.70      0.68        57
#            1       0.43      0.39      0.41        33
#
#     accuracy                           0.59        90
#    macro avg       0.55      0.55      0.55        90
# weighted avg       0.58      0.59      0.58        90

# %% [markdown]
# # Fitting Binary Tree

# %%
from sklearn.tree import DecisionTreeClassifier
decision_tree_classifier = DecisionTreeClassifier(random_state=42, max_depth=None)  # You can adjust the max_depth and other hyperparameters
decision_tree_classifier.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Predictions
tree_predictions = decision_tree_classifier.predict(x_test)

# Calculate accuracy
tree_accuracy = accuracy_score(y_test, tree_predictions)

# Print classification report
tree_classification_report = classification_report(y_test, tree_predictions)

# %%
print(f"Decision Tree Accuracy: {tree_accuracy}")
print(f"Decision Tree Classification Report:\n{tree_classification_report}")
# Out:
# Decision Tree Accuracy: 0.6111111111111112
# Decision Tree Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.75      0.71        57
#            1       0.46      0.36      0.41        33
#
#     accuracy                           0.61        90
#    macro avg       0.57      0.56      0.56        90
# weighted avg       0.59      0.61      0.60        90

# %% [markdown]
# # Fitting Gradient Boost

# %%
from sklearn.ensemble import GradientBoostingClassifier
gradient_boosting_classifier = GradientBoostingClassifier(n_estimators=100, random_state=42)  # You can adjust the number of estimators and other hyperparameters
gradient_boosting_classifier.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
# Predictions
gb_predictions = gradient_boosting_classifier.predict(x_test)

# Calculate accuracy
gb_accuracy = accuracy_score(y_test, gb_predictions)

# Print classification report
gb_classification_report = classification_report(y_test, gb_predictions)

print(f"Gradient Boosting Accuracy: {gb_accuracy}")
print(f"Gradient Boosting Classification Report:\n{gb_classification_report}")
# Out:
# Gradient Boosting Accuracy: 0.6111111111111112
# Gradient Boosting Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.68      0.74      0.71        57
#            1       0.46      0.39      0.43        33
#
#     accuracy                           0.61        90
#    macro avg       0.57      0.57      0.57        90
# weighted avg       0.60      0.61      0.60        90

# %% [markdown]
# # LogisticRegression Model Modification & Interpretation

# %%
inputs.columns.values
# Out:
# array(['Age_less than 11', 'Age_more than 14',
#        'Eating_location_Begging or collecting from dustbin',
#        'Sleeping_place_fixed_No', 'Aware_of_organizations_No',
#        'Work_hour_from 8 to 12 hr', 'Work_hour_more than 12 hr',
#        'Division_Barisal', 'Division_Chittagong', 'Division_Khulna',
#        'Division_Rajshahi', 'Division_Sylhet'], dtype=object)

# %%
feature_names = ['Age_less than 11', 'Age_more than 14',
       'Eating_location_Begging or collecting from dustbin',
       'Sleeping_place_fixed_No', 'Aware_of_organizations_No',
       'Work_hour_from 8 to 12 hr', 'Work_hour_more than 12 hr',
       'Division_Barisal', 'Division_Chittagong', 'Division_Khulna',
       'Division_Rajshahi', 'Division_Sylhet']

# %%
table = pd.DataFrame(columns =['Feature_names'],data = feature_names)

# %%
table['Coefficients'] = np.transpose(reg.coef_)

# %%
new_record = {'Feature_names': 'Intercept', 'Coefficients': -1.02698795 }
table.loc[-1] = new_record
table.index = table.index + 1
table = table.sort_index()

# %%
table['Odds Ratio'] = np.exp(table.Coefficients)
table
# Out:
#                                         Feature_names  Coefficients  \
# 0                                           Intercept     -1.026988
# 1                                    Age_less than 11     -0.125271
# 2                                    Age_more than 14     -0.579767
# 3   Eating_location_Begging or collecting from dus...      0.322248
# 4                             Sleeping_place_fixed_No     -0.387409
# 5                           Aware_of_organizations_No     -1.011010
# 6                           Work_hour_from 8 to 12 hr      0.774729
# 7                           Work_hour_more than 12 hr     -0.027089
# 8                                    Division_Barisal     -0.221527
# 9                                 Division_Chittagong     -0.204099
# 10                                    Division_Khulna     -0.089406
# 11                                  Division_Rajshahi      0.941861
# 12                                    Division_Sylhet     -1.179350
#
#     Odds Ratio
# 0     0.358084
# 1     0.882258
# 2     0.560029
# 3     1.380228
# 4     0.678813
# 5     0.363851
# 6     2.170004
# 7     0.973274
# 8     0.801294
# 9     0.815381
# 10    0.914474
# 11    2.564750
# 12    0.307479

# %%
table.sort_values('Odds Ratio', ascending = False)
# Out:
#                                         Feature_names  Coefficients  \
# 11                                  Division_Rajshahi      0.941861
# 6                           Work_hour_from 8 to 12 hr      0.774729
# 3   Eating_location_Begging or collecting from dus...      0.322248
# 7                           Work_hour_more than 12 hr     -0.027089
# 10                                    Division_Khulna     -0.089406
# 1                                    Age_less than 11     -0.125271
# 9                                 Division_Chittagong     -0.204099
# 8                                    Division_Barisal     -0.221527
# 4                             Sleeping_place_fixed_No     -0.387409
# 2                                    Age_more than 14     -0.579767
# 5                           Aware_of_organizations_No     -1.011010
# 0                                           Intercept     -1.026988
# 12                                    Division_Sylhet     -1.179350
#
#     Odds Ratio
# 11    2.564750
# 6     2.170004
# 3     1.380228
# 7     0.973274
# 10    0.914474
# 1     0.882258
# 9     0.815381
# 8     0.801294
# 4     0.678813
# 2     0.560029
# 5     0.363851
# 0     0.358084
# 12    0.307479

# %%
dummies_to_drop_nn = ['Work_hour_more than 12 hr','Division_Khulna','Age_less than 11']

# %%
inputs_nn = inputs.drop(dummies_to_drop_nn, axis =1)

# %%
#inputs_nn.to_csv('inputs_schhol.csv',index = False)
#targets.to_csv('targets_school.csv',index = False)

# %%
table = table.sort_values('Odds Ratio', ascending = False)

# %%
#table.to_csv('table.csv', index = False)

# %%
table
# Out:
#                                         Feature_names  Coefficients  \
# 11                                  Division_Rajshahi      0.941861
# 6                           Work_hour_from 8 to 12 hr      0.774729
# 3   Eating_location_Begging or collecting from dus...      0.322248
# 7                           Work_hour_more than 12 hr     -0.027089
# 10                                    Division_Khulna     -0.089406
# 1                                    Age_less than 11     -0.125271
# 9                                 Division_Chittagong     -0.204099
# 8                                    Division_Barisal     -0.221527
# 4                             Sleeping_place_fixed_No     -0.387409
# 2                                    Age_more than 14     -0.579767
# 5                           Aware_of_organizations_No     -1.011010
# 0                                           Intercept     -1.026988
# 12                                    Division_Sylhet     -1.179350
#
#     Odds Ratio
# 11    2.564750
# 6     2.170004
# 3     1.380228
# 7     0.973274
# 10    0.914474
# 1     0.882258
# 9     0.815381
# 8     0.801294
# 4     0.678813
# 2     0.560029
# 5     0.363851
# 0     0.358084
# 12    0.307479

# %%
# Calculate Wald confidence intervals
import scipy.stats as stats
coefficients = reg.coef_.flatten()
std_errors = np.sqrt(np.diag(np.linalg.inv(np.dot(x_train.T, x_train))))

alpha = 0.05
z_critical = stats.norm.ppf(1 - alpha / 2)

lower_bound = coefficients - z_critical * std_errors
upper_bound = coefficients + z_critical * std_errors

# Display or store results
results = pd.DataFrame({'Coefficient': np.exp(coefficients), 'Lower Bound': np.exp(lower_bound), 'Upper Bound': np.exp(upper_bound)})
print(results)
# Out:
#     Coefficient  Lower Bound  Upper Bound
# 0      0.882258     0.683894     1.138158
# 1      0.560029     0.422972     0.741496
# 2      1.380228     1.002229     1.900792
# 3      0.678813     0.510062     0.903395
# 4      0.363851     0.294318     0.449812
# 5      2.170004     1.737208     2.710623
# 6      0.973274     0.664571     1.425375
# 7      0.801294     0.499517     1.285388
# 8      0.815381     0.592562     1.121986
# 9      0.914474     0.577268     1.448657
# 10     2.564750     1.821763     3.610757
# 11     0.307479     0.216279     0.437135

# %%
results = results.sort_values('Coefficient', ascending = False)

# %%
#results.to_csv('CI.csv', index = False)
